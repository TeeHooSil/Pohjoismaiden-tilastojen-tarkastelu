# %% [markdown]
# # Materiaali haettu avoindata.fi. Nordstat: tilastoja Pohjoismaiden suurimmista kaupungeista ja kaupunkiseuduista
#
# # Tavoite löytää korrelaatioita rakennettuihin asuntoihin nähden.
#
# ## Tanskan data sisälsi vähiten puutteita. Joten valitsin käsitellä vain dataa Tanskaan liityen.
#
# ## Lisäksi Työvoiman vertailua Tanskassa, Suomessa ja Ruotsissa 1995-2019 välisenä aikana.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import seaborn as sns; sns.set_theme()

# %% [markdown]
# ## Valmistunet asuinhuoneistot huoneluvun mukaan Tanskassa 1993-2020

# %%
df_valmasuinhuon = pd.read_csv('Asuminen ja rakentaminen/Valmistuneet asuinhuoneistot huoneluvun mukaan/valmistuneetasuinhuoneistothuoneluvunmukaantanska.csv', encoding='latin-1')
df_valmasuinhuon
# Out:
#      Alue Huoneluku   1993   1994   1995   1996   1997   1998   1999   2000  \
# 0  Tanska         1     ..     ..     ..     ..     ..     ..     ..     ..
# 1  Tanska         2     ..     ..     ..     ..     ..     ..     ..     ..
# 2  Tanska         3     ..     ..     ..     ..     ..     ..     ..     ..
# 3  Tanska         4     ..     ..     ..     ..     ..     ..     ..     ..
# 4  Tanska        5+     ..     ..     ..     ..     ..     ..     ..     ..
# 5  Tanska  Yhteensä  14131  13787  13503  14239  17725  18156  17230  16334
#
#    ...   2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# 0  ...     ..     ..     ..     ..     ..     ..     ..     ..     ..     ..
# 1  ...     ..     ..     ..     ..     ..     ..     ..     ..     ..     ..
# 2  ...     ..     ..     ..     ..     ..     ..     ..     ..     ..     ..
# 3  ...     ..     ..     ..     ..     ..     ..     ..     ..     ..     ..
# ...

# %%
huoneistoluku = np.array(df_valmasuinhuon.iloc[5,3:], dtype='float')
vuosi = np.array([1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Valmistuneet asuinhuoneistot huoneluvun mukaan", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Huoneistoluku", loc="center", fontdict=font1)
plt.plot(vuosi, huoneistoluku)
plt.show()

# %% [markdown]
# # Väestönmuutokset Tanskassa 1992-2020

# %%
df_vaestonmuutokset = pd.read_csv('Vaestonmuutokset/Vaestonmuutokset/vaestonmuutoksettanska.csv', encoding='latin-1')
df_vaestonmuutokset
# Out:
#                   Alue           Väestönmuutos   1992   1993   1994   1995  \
# 0               Tanska  Väestönmuutos yhteensä  18367  15616  18818  35201
# 1  Kööpenhaminan seutu  Väestönmuutos yhteensä   5920   5685   8556  12484
# 2         Kööpenhamina  Väestönmuutos yhteensä   1439    897   3745   5261
# 3      Aalborgin seutu  Väestönmuutos yhteensä   1218    768    509   2553
# 4              Aalborg  Väestönmuutos yhteensä    669    878    895    944
# 5        Odensen seutu  Väestönmuutos yhteensä   1989   1278   1106   2851
# 6               Odense  Väestönmuutos yhteensä   1324    993    755    977
# 7        Århusin seutu  Väestönmuutos yhteensä   4372   4310   4997   6003
# 8                Århus  Väestönmuutos yhteensä   3372   3234   2932   2308
#
#     1996   1997   1998   1999  ...   2011   2012   2013   2014   2015   2016  \
# 0  23728  19462  18753  15937  ...  29096  29342  33267  42995  75364  42077
# ...

# %%
df_vaestonmuutokset_lisatyilla_asrvoilla = df_vaestonmuutokset

# %% [markdown]
# ### Puuttuvien arvojen täyttäminen "sopivalla" arvolla

# %%
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[2,15] = 1474
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[3,13] = 84
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[3,14] = 114
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[3,15] = 144
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[3,19] = 1267
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[4,7] = 480
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[5,8] = 323
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[6,8] = 187
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[6,10] = 405
df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[6,11] = 515

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Väestönmuutokset", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Henkilöluku", loc="center", fontdict=font1)
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[0,2:])
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[1,2:])
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[2,2:])
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[3,2:])
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[4,2:])
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[5,2:])
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[6,2:])
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[7,2:])
plt.plot(df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[8,2:])
plt.show()

# %%
huoneistoluku_0_0 = huoneistoluku[12:]
df_vaestonmuutokset_lisatyilla_asrvoilla_0_0 = df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[0,16:31]

df_vaestonmuutokset_lisatyilla_asrvoilla_0_11 = df_vaestonmuutokset_lisatyilla_asrvoilla.iloc[0,5:20]

huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_0 = np.array([huoneistoluku_0_0,df_vaestonmuutokset_lisatyilla_asrvoilla_0_0], dtype=float)
df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_0 = pd.DataFrame(data=huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_0,index=['Huoneistoluku','Väestömuutokset'],columns=['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020'])
df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_0 = df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_0.transpose()

huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_11 = np.array([huoneistoluku_0_0,df_vaestonmuutokset_lisatyilla_asrvoilla_0_11], dtype=float)
df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_11 = pd.DataFrame(data=huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_11,index=['Huoneistoluku','Väestömuutokset'],columns=['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020'])
df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_11 = df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_11.transpose()

# %% [markdown]
# ### Korrelaatio kun Huoneisto luku ja Väestömuutokset 2006-2020

# %%
df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_0.corr()
# Out:
#                  Huoneistoluku  Väestömuutokset
# Huoneistoluku         1.000000        -0.448552
# Väestömuutokset      -0.448552         1.000000

# %% [markdown]
# ### Korrelaatio kun Huoneisto luku 2006-2020 ja Väestömuutokset 1995-2009

# %%
df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_11.corr()
# Out:
#                  Huoneistoluku  Väestömuutokset
# Huoneistoluku         1.000000         0.808848
# Väestömuutokset       0.808848         1.000000

# %% [markdown]
# # Katsoin korrelaation huoneistolukujen ja väestönmuutosten välillä.
# ## Olin kiinostunut näkemään onko korrelaatio parempi, kun vertaa huoneistolukua väestömuutokseen siirrettynä takaisinpäin.
# ## Siirsin väestönmuutosta vuosi vuodelta taaksepäin 12 vuotta.
# # Paras korrelaatio löytyin kun väestönmuutos oli siirrettynä 11 vuotta ennen huoneistolukuja.

# %%
pd.plotting.scatter_matrix(df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_0,figsize=(10,10))
pd.plotting.scatter_matrix(df_huoneistoluku_0_0_df_vaestonmuutokset_lisatyilla_asrvoilla_0_11,figsize=(10,10))
plt.show()

# %% [markdown]
# # Asuntokanta talotyypin ja kerrostalohuoneistojen huoneluvun mukaan Tanskassa 1993-2020

# %%
df_asuntokanta = pd.read_csv('Asuminen ja rakentaminen/Asuntokanta talotyypin ja kerrostalohuoneistojen huoneluvun mukaan/askantatalotyypinjakerrostlhuonhuoneluvunmukaantanska.csv', encoding='latin-1')
df_asuntokanta = df_asuntokanta.iloc[:3,:30]
df_asuntokanta
# Out:
#      Alue  Talotyyppi  Yhteensä 1993  Yhteensä 1994  Yhteensä 1995  \
# 0  Tanska    Yhteensä        2402550        2412671        2426503
# 1  Tanska    Pientalo        1411766        1416800        1424100
# 2  Tanska  Kerrostalo         969682         974614         979741
#
#    Yhteensä 1996  Yhteensä 1997  Yhteensä 1998  Yhteensä 1999  Yhteensä 2000  \
# 0        2437255        2446967        2460608        2475587        2488972
# 1        1430244        1436753        1446270        1456843        1466746
# 2         984346         987881         992100         996805        1000476
#
#    ...  Yhteensä 2011  Yhteensä 2012  Yhteensä 2013  Yhteensä 2014  \
# 0  ...        2713724        2724149        2737575        2990238
# 1  ...        1596798        1603716        1610306        1617189
# 2  ...        1095553        1099850        1107880        1077811
#
#    Yhteensä 2015  Yhteensä 2016  Yhteensä 2017  Yhteensä 2018  Yhteensä 2019  \
# ...

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Asuntokanta talotyypin ja kerrostalohuoneistojen huoneluvun mukaan", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Huoneistoluku", loc="center", fontdict=font1)
plt.plot(df_asuntokanta.iloc[0,2:])
plt.plot(df_asuntokanta.iloc[1,2:])
plt.plot(df_asuntokanta.iloc[2,2:])
plt.legend(['Yht.','Pientalo','Kerrostalo'])
plt.show()

# %%
df_asuntokanta_column_muutettu = df_asuntokanta
df_asuntokanta_column_muutettu.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020'}, inplace=True)
df_asuntokanta_column_muutettu.iloc[:,:]
# Out:
#      Alue  Talotyyppi     1993     1994     1995     1996     1997     1998  \
# 0  Tanska    Yhteensä  2402550  2412671  2426503  2437255  2446967  2460608
# 1  Tanska    Pientalo  1411766  1416800  1424100  1430244  1436753  1446270
# 2  Tanska  Kerrostalo   969682   974614   979741   984346   987881   992100
#
#       1999     2000  ...     2011     2012     2013     2014     2015  \
# 0  2475587  2488972  ...  2713724  2724149  2737575  2990238  3001474
# 1  1456843  1466746  ...  1596798  1603716  1610306  1617189  1621856
# 2   996805  1000476  ...  1095553  1099850  1107880  1077811  1083662
#
#       2016     2017     2018     2019     2020
# 0  3013586  3030918  3056724  3082611  3113345
# 1  1628478  1635676  1642804  1649457  1660619
# 2  1089681  1099034  1112715  1128616  1146739
#
# [3 rows x 30 columns]

# %% [markdown]
# ### Pienitalo + Kerrostalo 1993-2020 vuosilta Tanskassa

# %%
asuntokanta_laskettu_yhteensa =  np.array([2381448,2391414,2403841,2414590,2424634,2438370,2453648,2467222,2487370,2501559,2519957,2540420,2580692,2604346,2629155,2654840,2680149,2677948,2692351,2703566,2718186,2695000,2705518,2718159,2734710,2755519,2778073,2807358])
asuntokanta_laskettu_yhteensa
# Out:
# array([2381448, 2391414, 2403841, 2414590, 2424634, 2438370, 2453648,
#        2467222, 2487370, 2501559, 2519957, 2540420, 2580692, 2604346,
#        2629155, 2654840, 2680149, 2677948, 2692351, 2703566, 2718186,
#        2695000, 2705518, 2718159, 2734710, 2755519, 2778073, 2807358])

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Asuntokanta talotyypin ja kerrostalohuoneistojen huoneluvun mukaan", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Huoneistoluku", loc="center", fontdict=font1)
plt.plot(asuntokanta_laskettu_yhteensa)
plt.plot(df_asuntokanta_column_muutettu.iloc[0,2:])
plt.plot(df_asuntokanta_column_muutettu.iloc[1,2:])
plt.plot(df_asuntokanta_column_muutettu.iloc[2,2:])
plt.legend(['P.talo + K.talo.','Yht.','Pientalo','Kerrostalo'])
plt.show()

# %% [markdown]
# ## Kun laskee yhteen pinetalo ja kerrostalohuoneistojen huoneluvut, niin saa pienemmät arvot kuin datan antama yhteensä arvo.
# ## Lasketaanko mahdollisesti yhteensä arvoihin jotain mitä ei ilmoiteta datan tiedoissa?

# %% [markdown]
# ## Yllä asuntokunnat henkilöluvun mukaan. Myös näytettynä asuntokunnissa olevat 0-17 vuotiaat.

# %% [markdown]
# # Työikäinen väestö Tanskassa 1993-2020

# %%
df_tyoikainenvaesto = pd.read_csv('Tpaikat ja tvoima/Tik vst/tyoikainenvaestotanska.csv', encoding='latin-1')
df_tyoikainenvaesto_column_names = df_tyoikainenvaesto
df_tyoikainenvaesto_column_names.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työikäinen väestö yhteensä, miehet ja naiset Tanskassa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Henkilöluku", loc="center", fontdict=font1)
plt.plot(df_tyoikainenvaesto_column_names.iloc[5,2:30])
plt.plot(df_tyoikainenvaesto_column_names.iloc[5,30:58])
plt.plot(df_tyoikainenvaesto_column_names.iloc[5,58:88])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työikäinen väestö Suomessa 1993-2020

# %%
df_tyoikainenvaesto_suomi = pd.read_csv('Tpaikat ja tvoima/Tik vst/tyoikainenvaestosuomi.csv', encoding='latin-1')
df_tyoikainenvaesto_suomi_column_names = df_tyoikainenvaesto_suomi
df_tyoikainenvaesto_suomi_column_names.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työikäinen väestö yhteensä, miehet ja naiset Suomessa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Henkilöluku", loc="center", fontdict=font1)
plt.plot(df_tyoikainenvaesto_suomi_column_names.iloc[5,2:30])
plt.plot(df_tyoikainenvaesto_suomi_column_names.iloc[5,30:58])
plt.plot(df_tyoikainenvaesto_suomi_column_names.iloc[5,58:88])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työikäinen väestö Ruotsissa 1993-2020

# %%
df_tyoikainenvaesto_ruotsi = pd.read_csv('Tpaikat ja tvoima/Tik vst/tyoikainenvaestoruotsi.csv', encoding='latin-1')
df_tyoikainenvaesto_ruotsi_column_names = df_tyoikainenvaesto_ruotsi
df_tyoikainenvaesto_ruotsi_column_names.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työikäinen väestö yhteensä, miehet ja naiset Ruotsissa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Henkilöluku", loc="center", fontdict=font1)
plt.plot(df_tyoikainenvaesto_ruotsi_column_names.iloc[5,2:30])
plt.plot(df_tyoikainenvaesto_ruotsi_column_names.iloc[5,30:58])
plt.plot(df_tyoikainenvaesto_ruotsi_column_names.iloc[5,58:88])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työikäinen väestö Tanskassa, Suomessa ja Ruotsissa 1993-2020

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työikäinen väestö yhteensä Tanskassa, Suomessa ja Ruotsissa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Henkilöluku", loc="center", fontdict=font1)
plt.plot(df_tyoikainenvaesto_column_names.iloc[5,2:30])
plt.plot(df_tyoikainenvaesto_suomi_column_names.iloc[5,2:30])
plt.plot(df_tyoikainenvaesto_ruotsi_column_names.iloc[5,2:30])
plt.legend(['Yht. Tanska','Yht. Suomi','Yht. Ruotsi'])
plt.show()

# %% [markdown]
# # Työttömät työnhakijat Tanskassa 1995-2019

# %%
df_tyottomattyonhakijat = pd.read_csv('Tpaikat ja tvoima/Tttomat tnhakijat/tyottomattyonhakijattanska.csv', encoding='latin-1')
df_tyottomattyonhakijat_indexing = df_tyottomattyonhakijat
df_tyottomattyonhakijat_indexing.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työttömät työnhakijat yhteensä, miehet ja naiset Tanskassa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Työttömien työnhakijoiden määrä", loc="center", fontdict=font1)
plt.plot(df_tyottomattyonhakijat_indexing.iloc[0,2:27])
plt.plot(df_tyottomattyonhakijat_indexing.iloc[0,28:53])
plt.plot(df_tyottomattyonhakijat_indexing.iloc[0,54:79])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työttömät työnhakijat Suomessa 1995-2019

# %%
df_tyottomattyonhakijat_suomi = pd.read_csv('Tpaikat ja tvoima/Tttomat tnhakijat/tyottomattyonhakijatsuomi.csv', encoding='latin-1')
df_tyottomattyonhakijat_suomi_indexing = df_tyottomattyonhakijat_suomi
df_tyottomattyonhakijat_suomi_indexing.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työttömät työnhakijat yhteensä, miehet ja naiset Suomessa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Työttömien työnhakijoiden määrä", loc="center", fontdict=font1)
plt.plot(df_tyottomattyonhakijat_suomi_indexing.iloc[0,2:26])
plt.plot(df_tyottomattyonhakijat_suomi_indexing.iloc[0,26:50])
plt.plot(df_tyottomattyonhakijat_suomi_indexing.iloc[0,50:74])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työttömät työnhakijat Ruotsissa 1995-2019

# %%
df_tyottomattyonhakijat_ruotsi = pd.read_csv('Tpaikat ja tvoima/Tttomat tnhakijat/tyottomattyonhakijatruotsi.csv', encoding='latin-1')
df_tyottomattyonhakijat_ruotsi_indexing = df_tyottomattyonhakijat_ruotsi
df_tyottomattyonhakijat_ruotsi_indexing.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työttömät työnhakijat yhteensä, miehet ja naiset", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Työttömien työnhakijoiden määrä", loc="center", fontdict=font1)
plt.plot(df_tyottomattyonhakijat_ruotsi_indexing.iloc[0,2:26])
plt.plot(df_tyottomattyonhakijat_ruotsi_indexing.iloc[0,26:50])
plt.plot(df_tyottomattyonhakijat_ruotsi_indexing.iloc[0,50:74])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työttömät työnhakijat Tanskassa, Suomessa ja Ruotsissa 1995-2019

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työttömät työnhakijat yhteensä Tanskassa, Suomessa ja Ruotsissa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Työttömien työnhakijoiden määrä", loc="center", fontdict=font1)
plt.plot(df_tyottomattyonhakijat_indexing.iloc[0,2:26])
plt.plot(df_tyottomattyonhakijat_suomi_indexing.iloc[0,2:26])
plt.plot(df_tyottomattyonhakijat_ruotsi_indexing.iloc[0,2:26])
plt.legend(['Yht. Tanska','Yht. Suome','Yht. Ruotsi'])
plt.show()

# %% [markdown]
# # Työllinen työvoima Tanskassa 1995-2020

# %%
df_tyollinentyovoima = pd.read_csv('Tpaikat ja tvoima/Tllinen tvoima/tyollinentyovoimatanska.csv', encoding='latin-1')
df_tyollinentyovoima
# Out:
#      Alue                          Ikä  Yhteensä 1995  Yhteensä 1996  \
# 0  Tanska  Työllinen työvoima yhteensä        2340400        2376362
# 1  Tanska                        20-24         259815         271000
# 2  Tanska                        25-29         307736         302835
# 3  Tanska                        30-49        1264980        1274320
# 4  Tanska                        50-64         507869         528207
#
#    Yhteensä 1997  Yhteensä 1998  Yhteensä 1999  Yhteensä 2000  Yhteensä 2001  \
# 0        2407434        2446289        2497657        2514877        2532098
# 1         270818         265904         263750         256307         245572
# 2         297578         299822         305302         306783         308715
# 3        1283478        1295136        1311436        1313303        1318456
# 4         555560         585427         617169         638484         659355
#
#    Yhteensä 2002  ...  Naiset 2011  Naiset 2012  Naiset 2013  Naiset 2014  \
# ...

# %%
df_tyollinentyovoima_column_names = df_tyollinentyovoima
df_tyollinentyovoima_column_names.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työllinen työvoima yhteensä, miehet ja naiset Tanskassa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Töissä käyvien määrä", loc="center", fontdict=font1)
plt.plot(df_tyollinentyovoima.iloc[0,2:27])
plt.plot(df_tyollinentyovoima.iloc[0,28:53])
plt.plot(df_tyollinentyovoima.iloc[0,54:79])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työllinen työvoima Suomessa 1995-2020

# %%
df_tyollinentyovoima_suomi = pd.read_csv('Tpaikat ja tvoima/Tllinen tvoima/tyollinentyovoimasuomi.csv', encoding='latin-1')
df_tyollinentyovoima_suomi
# Out:
#     Alue                          Ikä  Yhteensä 1995  Yhteensä 1996  \
# 0  Suomi  Työllinen työvoima yhteensä        1883525        1896966
# 1  Suomi                        20-24         107714         111253
# 2  Suomi                        25-29         214433         210271
# 3  Suomi                        30-49        1182139        1183402
# 4  Suomi                        50-64         379239         392040
#
#    Yhteensä 1997  Yhteensä 1998  Yhteensä 1999  Yhteensä 2000  Yhteensä 2001  \
# 0        1920250        1997051        2067863        2104079        2155551
# 1         116261         131649         153245         161912         168456
# 2         208166         209657         209061         212229         219736
# 3        1181150        1199349        1205214        1198127        1199469
# 4         414673         456396         500343         531811         567890
#
#    Yhteensä 2002  ...  Naiset 2011  Naiset 2012  Naiset 2013  Naiset 2014  \
# ...

# %%
df_tyollinentyovoima_suomi_column_names = df_tyollinentyovoima_suomi
df_tyollinentyovoima_suomi_column_names.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työllinen työvoima yhteensä, miehet ja naiset Suomessa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Töissä käyvien määrä", loc="center", fontdict=font1)
plt.plot(df_tyollinentyovoima_suomi_column_names.iloc[0,2:27])
plt.plot(df_tyollinentyovoima_suomi_column_names.iloc[0,28:53])
plt.plot(df_tyollinentyovoima_suomi_column_names.iloc[0,54:79])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työllinen työvoima Ruotsissa 1995-2020

# %%
df_tyollinentyovoima_ruotsi = pd.read_csv('Tpaikat ja tvoima/Tllinen tvoima/tyollinentyovoimaruotsi.csv', encoding='latin-1')
df_tyollinentyovoima_ruotsi
# Out:
#      Alue                          Ikä  Yhteensä 1995  Yhteensä 1996  \
# 0  Ruotsi  Työllinen työvoima yhteensä        3666821        3708044
# 1  Ruotsi                        20-24         295602         297636
# 2  Ruotsi                        25-29         437148         430878
# 3  Ruotsi                        30-49        1957215        1958624
# 4  Ruotsi                        50-64         976856        1020906
#
#    Yhteensä 1997  Yhteensä 1998  Yhteensä 1999  Yhteensä 2000  Yhteensä 2001  \
# 0        3703487        3688492        3782780        3833439        3922375
# 1         279355         270376         293053         280149         302101
# 2         421041         408451         419734         432963         440321
# 3        1942587        1925419        1945972        1965835        1989636
# 4        1060504        1084246        1124521        1154492        1190317
#
#    Yhteensä 2002  ...  Naiset 2011  Naiset 2012  Naiset 2013  Naiset 2014  \
# ...

# %%
df_tyollinentyovoima_ruotsi_column_names = df_tyollinentyovoima_ruotsi
df_tyollinentyovoima_ruotsi_column_names.rename(columns={'Yhteensä 1993': '1993', 'Yhteensä 1994': '1994', 'Yhteensä 1995': '1995', 'Yhteensä 1996': '1996', 'Yhteensä 1997': '1997', 'Yhteensä 1998': '1998', 'Yhteensä 1999': '1999', 'Yhteensä 2000': '2000', 'Yhteensä 2001': '2001', 'Yhteensä 2002': '2002', 'Yhteensä 2003': '2003', 'Yhteensä 2004': '2004', 'Yhteensä 2005': '2005', 'Yhteensä 2006': '2006', 'Yhteensä 2007': '2007', 'Yhteensä 2008': '2008', 'Yhteensä 2009': '2009', 'Yhteensä 2010': '2010', 'Yhteensä 2011': '2011', 'Yhteensä 2012': '2012', 'Yhteensä 2013': '2013', 'Yhteensä 2014': '2014', 'Yhteensä 2015': '2015', 'Yhteensä 2016': '2016', 'Yhteensä 2017': '2017', 'Yhteensä 2018': '2018', 'Yhteensä 2019': '2019', 'Yhteensä 2020': '2020','Miehet 1993': '1993', 'Miehet 1994': '1994', 'Miehet 1995': '1995', 'Miehet 1996': '1996', 'Miehet 1997': '1997', 'Miehet 1998': '1998', 'Miehet 1999': '1999', 'Miehet 2000': '2000', 'Miehet 2001': '2001', 'Miehet 2002': '2002', 'Miehet 2003': '2003', 'Miehet 2004': '2004', 'Miehet 2005': '2005', 'Miehet 2006': '2006', 'Miehet 2007': '2007', 'Miehet 2008': '2008', 'Miehet 2009': '2009', 'Miehet 2010': '2010', 'Miehet 2011': '2011', 'Miehet 2012': '2012', 'Miehet 2013': '2013', 'Miehet 2014': '2014', 'Miehet 2015': '2015', 'Miehet 2016': '2016', 'Miehet 2017': '2017', 'Miehet 2018': '2018', 'Miehet 2019': '2019', 'Miehet 2020': '2020','Naiset 1993': '1993', 'Naiset 1994': '1994', 'Naiset 1995': '1995', 'Naiset 1996': '1996', 'Naiset 1997': '1997', 'Naiset 1998': '1998', 'Naiset 1999': '1999', 'Naiset 2000': '2000', 'Naiset 2001': '2001', 'Naiset 2002': '2002', 'Naiset 2003': '2003', 'Naiset 2004': '2004', 'Naiset 2005': '2005', 'Naiset 2006': '2006', 'Naiset 2007': '2007', 'Naiset 2008': '2008', 'Naiset 2009': '2009', 'Naiset 2010': '2010', 'Naiset 2011': '2011', 'Naiset 2012': '2012', 'Naiset 2013': '2013', 'Naiset 2014': '2014', 'Naiset 2015': '2015', 'Naiset 2016': '2016', 'Naiset 2017': '2017', 'Naiset 2018': '2018', 'Naiset 2019': '2019', 'Naiset 2020': '2020'}, inplace=True)

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työllinen työvoima yhteensä, miehet ja naiset Suomessa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Töissä käyvien määrä", loc="center", fontdict=font1)
plt.plot(df_tyollinentyovoima_ruotsi_column_names.iloc[0,2:27])
plt.plot(df_tyollinentyovoima_ruotsi_column_names.iloc[0,28:53])
plt.plot(df_tyollinentyovoima_ruotsi_column_names.iloc[0,54:79])
plt.legend(['Yht.','Miehet','Naiset'])
plt.show()

# %% [markdown]
# # Työllinen työvoima Tanskassa, Suomessa ja Ruotsissa 1995-2020

# %%
plt.figure(figsize=(15, 10))
font1 = {'family':'serif','color':'blue','size':12}
plt.title("Työllinen työvoima yhteensä Tanskassa, Suomessa ja Ruotsissa", fontdict=font1)
plt.xlabel("Vuosi", loc="center", labelpad=0, fontdict=font1)
plt.ylabel("Töissä käyvien määrä", loc="center", fontdict=font1)
plt.plot(df_tyollinentyovoima.iloc[0,2:27])
plt.plot(df_tyollinentyovoima_suomi_column_names.iloc[0,2:27])
plt.plot(df_tyollinentyovoima_ruotsi_column_names.iloc[0,2:27])
plt.legend(['Yht. Tanska','Yht. Suomi','Yht. Ruotsi'])
plt.show()
